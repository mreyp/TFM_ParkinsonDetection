# %% [markdown]
# # Generation of new audios using BigVSAN

# %% [markdown]
# ## 1. Pretrained with LibriTTS data

# %% [markdown]
# ### Inference (generation) 150 HC & 150 PD (1 iteration, no noise added)

# %%
# !python 'TFM_MartaRey/BigVSAN/inference.py' \
--checkpoint_file 'TFM_MartaRey/BigVSAN/bigvsan_10mstep/g_10000000' \
--input_wavs_dir 'TFM_MartaRey/datos/control_files_short_24khz' \
--output_dir 'TFM_MartaRey/datos/generados/pretrained_10ms_BigVSAN_generated_control' \
--iterations 1 \
--adjustment_factor 0.0
# Out:
# /home/v890/v890699/miniconda3/envs/TFM/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Loading 'TFM_MartaRey/BigVSAN/bigvsan_10mstep/g_10000000'
# Complete.
# Removing weight norm...
#
# Initializing Inference Process for iteration 1...
# Added noise with 0.0 factor
# /media/beegfs/home/v890/v890699/TFM_MartaRey/BigVSAN/inference.py:54: FutureWarning: Pass sr=24000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav, sr = librosa.load(os.path.join(a.input_wavs_dir, filname), h.sampling_rate, mono=True)
# ...

# %%
# !python 'TFM_MartaRey/BigVSAN/inference.py' \
--checkpoint_file 'TFM_MartaRey/BigVSAN/bigvsan_10mstep/g_10000000' \
--input_wavs_dir 'TFM_MartaRey/datos/pathological_files_short_24khz' \
--output_dir 'TFM_MartaRey/datos/generados/pretrained_10ms_BigVSAN_generated_pathological' \
--iterations 1 \
--adjustment_factor 0.0
# Out:
# /home/v890/v890699/miniconda3/envs/TFM/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Loading 'TFM_MartaRey/BigVSAN/bigvsan_10mstep/g_10000000'
# Complete.
# Removing weight norm...
#
# Initializing Inference Process for iteration 1...
# Added noise with 0.0 factor
# /media/beegfs/home/v890/v890699/TFM_MartaRey/BigVSAN/inference.py:54: FutureWarning: Pass sr=24000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav, sr = librosa.load(os.path.join(a.input_wavs_dir, filname), h.sampling_rate, mono=True)
# ...

# %%
### Pretrained model with less iterations (worse)
# !python inference.py \
--checkpoint_file './BigVSAN/bigvsan_1mstep/g_01000000' \
--input_wavs_dir '../datos/control_files_short_24khz' \
--output_dir '../datos/generados/pretrained_1ms_BigVSAN_generated_control' \
--iterations 1 \
--adjustment_factor 0.0
# Out:
# /home/v890/v890699/miniconda3/envs/TFM/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Loading 'TFM_MartaRey/BigVSAN/bigvsan_1mstep/g_01000000'
# Complete.
# Removing weight norm...
#
# Initializing Inference Process for iteration 1...
# Added noise with 0.0 factor
# /media/beegfs/home/v890/v890699/TFM_MartaRey/BigVSAN/inference.py:54: FutureWarning: Pass sr=24000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav, sr = librosa.load(os.path.join(a.input_wavs_dir, filname), h.sampling_rate, mono=True)
# ...

# %%
### Pretrained model with less iterations (worse)
# !python inference.py \
--checkpoint_file './BigVSAN/bigvsan_1mstep/g_01000000' \
--input_wavs_dir '../datos/pathological_files_short_24khz' \
--output_dir '../datos/generados/pretrained_1ms_BigVSAN_generated_pathological' \
--iterations 1 \
--adjustment_factor 0.0
# Out:
# /home/v890/v890699/miniconda3/envs/TFM/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Loading 'TFM_MartaRey/BigVSAN/bigvsan_1mstep/g_01000000'
# Complete.
# Removing weight norm...
#
# Initializing Inference Process for iteration 1...
# Added noise with 0.0 factor
# /media/beegfs/home/v890/v890699/TFM_MartaRey/BigVSAN/inference.py:54: FutureWarning: Pass sr=24000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav, sr = librosa.load(os.path.join(a.input_wavs_dir, filname), h.sampling_rate, mono=True)
# ...

# %% [markdown]
# ### Inference (generation) (iterations, added random noise)

# %%
# Random 1e-6
# !python inference.py \
--checkpoint_file './BigVSAN/bigvsan_10mstep/g_10000000' \
--input_wavs_dir '../datos/control_files_short_24khz' \
--output_dir '../datos/generados/pretrained_40_1e6_BigVSAN_generated_control' \
--iterations 40 \
--adjustment_factor 1e-6

# %%
# Random 1e-6
# !python inference.py \
--checkpoint_file './bigvsan_10mstep/g_10000000' \
--input_wavs_dir '../datos/pathological_files_short_24khz' \
--output_dir '../datos/generados/pretrained_40_1e6_BigVSAN_generated_pathological' \
--iterations 40 \
--adjustment_factor 1e-6

# %%
# Random 1e-5
# !python 'TFM_MartaRey/BigVSAN/inference.py' \
--checkpoint_file 'TFM_MartaRey/BigVSAN/bigvsan_10mstep/g_10000000' \
--input_wavs_dir 'TFM_MartaRey/datos/control_files_short_24khz' \
--output_dir 'TFM_MartaRey/datos/generados/pretrained_40_1e5_BigVSAN_generated_control' \
--iterations 40 \
--adjustment_factor 1e-5
# Out:
# /home/v890/v890699/miniconda3/envs/TFM_new/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Loading 'TFM_MartaRey/BigVSAN/bigvsan_10mstep/g_10000000'
# Complete.
# Removing weight norm...
#
# Initializing Inference Process for iteration 1...
# Added noise with 1e-05 factor
# /media/beegfs/home/v890/v890699/TFM_MartaRey/BigVSAN/inference.py:54: FutureWarning: Pass sr=24000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav, sr = librosa.load(os.path.join(a.input_wavs_dir, filname), h.sampling_rate, mono=True)
# ...

# %%
# Random 1e-5
# !python 'TFM_MartaRey/BigVSAN/inference.py' \
--checkpoint_file 'TFM_MartaRey/BigVSAN/bigvsan_10mstep/g_10000000' \
--input_wavs_dir 'TFM_MartaRey/datos/pathological_files_short_24khz' \
--output_dir 'TFM_MartaRey/datos/generados/pretrained_40_1e5_BigVSAN_generated_pathological' \
--iterations 40 \
--adjustment_factor 1e-5
# Out:
# /home/v890/v890699/miniconda3/envs/TFM_new/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Loading 'TFM_MartaRey/BigVSAN/bigvsan_10mstep/g_10000000'
# Complete.
# Removing weight norm...
#
# Initializing Inference Process for iteration 1...
# Added noise with 1e-05 factor
# /media/beegfs/home/v890/v890699/TFM_MartaRey/BigVSAN/inference.py:54: FutureWarning: Pass sr=24000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   wav, sr = librosa.load(os.path.join(a.input_wavs_dir, filname), h.sampling_rate, mono=True)
# ...

# %%
# Random 1e-4
# !python inference.py \
--checkpoint_file './bigvsan_10mstep/g_10000000' \
--input_wavs_dir '../datos/control_files_short_24khz' \
--output_dir '../datos/generados/pretrained_40_1e4_BigVSAN_generated_control' \
--iterations 40 \
--adjustment_factor 1e-4

# %%
# Random 1e-4
# !python inference.py \
--checkpoint_file './bigvsan_10mstep/g_10000000' \
--input_wavs_dir '../datos/pathological_files_short_24khz' \
--output_dir '../datos/generados/pretrained_40_1e4_BigVSAN_generated_pathological' \
--iterations 40 \
--adjustment_factor 1e-4

# %%
# Random 1e-3
# !python inference.py \
--checkpoint_file './bigvsan_10mstep/g_10000000' \
--input_wavs_dir '../datos/control_files_short_24khz' \
--output_dir '../datos/generados/pretrained_40_1e3_BigVSAN_generated_control' \
--iterations 40 \
--adjustment_factor 1e-3

# %%
# Random 1e-3
# !python inference.py \
--checkpoint_file './bigvsan_10mstep/g_10000000' \
--input_wavs_dir '../datos/pathological_files_short_24khz' \
--output_dir '../datos/generados/pretrained_40_1e3_BigVSAN_generated_pathological' \
--iterations 40 \
--adjustment_factor 1e-3

# %% [markdown]
# ### Sequential generation

# %%
# !python inference_sequential.py \
--checkpoint_file './BigVSAN/bigvsan_10mstep/g_10000000' \
--input_wavs_dir '../datos/control_files_short_24khz' \
--output_dir '../datos/generados/pretrained_seq_40_BigVSAN_generated_control' \
--iterations 40

# %%
# !python inference_sequential.py \
--checkpoint_file './BigVSAN/bigvsan_10mstep/g_10000000' \
--input_wavs_dir '../datos/pathological_files_short_24khz' \
--output_dir '../datos/generados/pretrained_seq_40_BigVSAN_generated_pathological' \
--iterations 40
